# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import pathlib
from typing import Tuple, List

# %%
## Self explanatory
save_plots = True

## Toggle plot titles (off for thesis and papers, generally speaking)
show_titles = False

## Toggle plot grid
show_grid = False

## If true, require DTF with double m.c. to be successful
dtf_success = True

## If true, print plots in b&w to bankrupt thesis shops
bw = True

# %%
## Create plots directory, if missing
plot_directory = (str(pathlib.Path.home())
                  + '/preliminary-variable-studies/'
                  + 'plots/'
                  + 'lambda_endvertex_study/'
)
pathlib.Path(plot_directory).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# # Import data

# %%
input_mc = str(pathlib.Path.home()) + '/data/LHCbMC_2016-2017-2018_MagUpDown_Lb2JPsiL_Ttracks_v12.h5'

# %%
df_reco = pd.read_hdf(input_mc, key='LHCbMC_Lb')
df_reco
# Out:
#          Lb_ENDVERTEX_X  Lb_ENDVERTEX_Y  Lb_ENDVERTEX_Z  L_ENDVERTEX_X  \
# Rec_key
# 0              0.952388       -0.165336       26.651770     402.777832
# 1              0.845292       -0.195122        3.622388     139.395874
# 2             -0.480003       -0.762014       18.670696    -819.340149
# 3              1.681797       -2.255294      -36.569271     113.645294
# 4              0.824895       -0.252737       74.871048    -100.702072
# ...                 ...             ...             ...            ...
# 366391         0.964920        0.161698      -12.157676     293.129822
# 366392        -0.498788        1.215896       21.856564    -176.847626
# 366393         0.114458       -0.046962       25.276293     -29.465662
# 366394         1.096764       -0.076485      -13.951857      42.977512
# 366395         1.382697        0.157468       79.494102     482.254425
#
#          L_ENDVERTEX_Y  L_ENDVERTEX_Z  Jpsi_ENDVERTEX_X  Jpsi_ENDVERTEX_Y  \
# Rec_key
# 0          -229.470520    5536.814453            0.9524           -0.1653
# 1           322.585419    7428.522461            0.8453           -0.1950
# 2          -626.124390    5389.564453           -0.4801           -0.7620
# 3          -329.222229    4678.392090            1.6818           -2.2553
# 4            60.565861    6466.218750            0.8242           -0.2542
# ...                ...            ...               ...               ...
# 366391       39.016293    7097.797363            0.9649            0.1621
# 366392      145.914993    8691.596680           -0.5001            1.2166
# 366393      -15.364128     949.110657            0.1145           -0.0469
# 366394     -134.660324    4807.495117            1.0967           -0.0764
# 366395     -270.556763    6824.267578            1.3827            0.1575
#
#          Jpsi_ENDVERTEX_Z         L_PX  ...  DTF_FixJPsiLambda_PIDSubs_p_PY  \
# Rec_key                                 ...
# 0               26.652201  1910.136719  ...                     -186.566345
# 1                3.620400   481.652618  ...                      222.666214
# 2               18.671101 -5395.257812  ...                     -323.442810
# 3              -36.569199  7835.708984  ...                    -1702.511353
# 4               74.883598   -74.406654  ...                      135.662018
# ...                   ...          ...  ...                             ...
# 366391         -12.151800  3175.616943  ...                      -18.306223
# 366392          21.869101 -2664.720215  ...                      -50.586430
# 366393          25.275400 -6107.898926  ...                     -133.646973
# 366394         -13.952700  -279.406677  ...                      -92.683861
# 366395          79.494202  3857.519287  ...                      -79.852051
#
#          DTF_FixJPsiLambda_PIDSubs_p_PZ  DTF_FixJPsiLambda_PIDSubs_mum_PX  \
# Rec_key
# 0                           5411.963379                       -804.469727
# 1                           4137.976074                       -605.608093
# 2                           2628.927246                          4.108163
# 3                          24506.517578                       8712.822266
# 4                           8106.856445                      -3448.149902
# ...                                 ...                               ...
# 366391                      7767.518555                       1504.345581
# 366392                     -2812.631592                      -3547.666504
# 366393                     15975.192383                      -3526.683594
# 366394                      3969.945801                       1982.495117
# 366395                      1969.780762                       2975.557617
#
#          DTF_FixJPsiLambda_PIDSubs_mum_PY  DTF_FixJPsiLambda_PIDSubs_mum_PZ  \
# Rec_key
# 0                             -535.944397                      22858.960938
# 1                              594.454895                      11170.495117
# 2                             -790.314697                       5651.807129
# 3                           -18033.572266                     231397.500000
# 4                            -1045.294434                      90591.554688
# ...                                   ...                               ...
# 366391                         715.472656                      49351.718750
# 366392                        1885.741577                      33505.289062
# 366393                        -343.335175                      44636.988281
# 366394                       -2486.259033                      26074.431641
# 366395                       -1001.848267                      23227.001953
#
#          DTF_FixJPsiLambda_PIDSubs_mup_PX  DTF_FixJPsiLambda_PIDSubs_mup_PY  \
# Rec_key
# 0                             1438.071777                       1619.347290
# 1                               71.893692                      -2873.631348
# 2                            -5579.078613                       -431.151581
# 3                              336.531647                      -3496.248779
# 4                              588.637329                        239.301941
# ...                                   ...                               ...
# 366391                        -112.221489                       2933.706299
# 366392                       -1337.816284                       1466.083374
# 366393                       -3534.635254                      -3121.734619
# 366394                        2165.314453                        -46.072693
# 366395                        6022.983887                       2011.241821
#
#          DTF_FixJPsiLambda_PIDSubs_mup_PZ  TrackType   MC_key
# Rec_key
# 0                            23634.302734          T        0
# 1                            73489.484375          T       29
# 2                            23151.667969          T       69
# 3                            45100.238281          T      119
# 4                            10912.332031          T       -1
# ...                                   ...        ...      ...
# 366391                       37641.914062          T  8921673
# 366392                       45027.328125          T  8921702
# 366393                       91762.195312          T  8921772
# 366394                       39433.843750          T  8921784
# 366395                       61724.515625          T  8921805
#
# [366396 rows x 154 columns]

# %%
df_truth = pd.read_hdf(input_mc, key='LHCbMCTruth_Lb')
df_truth
# Out:
#          MCTRUTH_Lb_ENDVERTEX_X  MCTRUTH_Lb_ENDVERTEX_Y  \
# MC_key
# 0                        0.9512                 -0.1669
# 1                        0.4619                 -0.3471
# 2                        0.8623                 -0.0693
# 3                        0.8441                 -0.1694
# 4                        0.6610                 -0.4327
# ...                         ...                     ...
# 8921810                  0.7382                 -0.1062
# 8921811                  0.6401                 -0.0814
# 8921812                  2.0908                 -1.0901
# 8921813                  1.3535                  1.5125
# 8921814                  1.0864                  0.0211
#
#          MCTRUTH_Lb_ENDVERTEX_Z  MCTRUTH_L_ENDVERTEX_X  MCTRUTH_L_ENDVERTEX_Y  \
# MC_key
# 0                     26.401600             343.742889            -192.429398
# 1                    -52.081200             -19.765400             -33.384300
# 2                     39.078201             145.114395             -70.015701
# 3                     17.714300              -9.207400              27.546700
# 4                      7.083600             -23.592199             -54.290798
# ...                         ...                    ...                    ...
# 8921810                0.347100              -2.454600               0.459400
# 8921811               27.420200               4.920900             -10.475100
# 8921812               46.602200              36.268501             -29.632999
# 8921813                0.694100             147.764999             156.474701
# 8921814               18.347000              25.720200             -20.035601
#
#          MCTRUTH_L_ENDVERTEX_Z  MCTRUTH_p_PX  MCTRUTH_p_PY   MCTRUTH_p_PZ  \
# MC_key
# 0                  4751.548828   2031.640015  -1218.119995   29336.890625
# 1                    45.136002  -1190.050049  -1817.560059    5618.410156
# 2                  2563.685059   1349.000000   -574.190002   22276.189453
# 3                  3520.887207   -295.320007    790.229980   93841.296875
# 4                   201.384293  -1843.489990  -4303.959961   15525.910156
# ...                        ...           ...           ...            ...
# 8921810              68.980499  -1052.079956    169.649994   21721.480469
# 8921811              58.229698    680.200012  -1542.880005    4852.310059
# 8921812            1175.768677   4569.680176  -3904.929932  153438.671875
# 8921813            1460.922485   2323.729980   2452.239990   22514.330078
# 8921814             380.729614   1912.170044  -1527.989990   29026.580078
#
#          MCTRUTH_pim_PX  ...  mup_PP_X  mup_PP_Y   mup_PP_Z    mup_PP_PX  \
# MC_key                   ...
# 0            445.510010  ...    0.6208   -0.5355  21.231701  1448.819824
# 1           -125.169998  ...    0.2795   -0.4641 -50.938000 -3430.944092
# 2            239.940002  ...    0.1603   -0.3852  34.265598  1869.628418
# 3              3.170000  ...    0.4994   -0.5171  14.525300   491.177612
# 4           -361.470001  ...   -0.0085   -0.3661   9.187500 -2067.989014
# ...                 ...  ...       ...       ...        ...          ...
# 8921810     -270.470001  ...    0.5466   -0.3809   3.584800 -1646.731689
# 8921811      153.279999  ...       NaN       NaN        NaN          NaN
# 8921812      582.070007  ...    0.3603    0.4048  30.488100  1073.656860
# 8921813      227.960007  ...    0.1721    1.6476  -7.021200   818.388855
# 8921814      463.820007  ...    0.0141   -0.0873  13.923100  2344.837646
#
#            mup_PP_PY     mup_PP_PZ  mup_PP_Weight  Rec_key  N_rec_matches  \
# MC_key
# 0        1628.266357  23763.910156       0.975000        0              1
# 1       -2054.681885  20444.863281       1.000000       -1              0
# 2         869.200012  13080.188477       1.000000       -1              0
# 3         513.784912   5034.924805       1.000000       -1              0
# 4          93.588974   6374.103027       1.000000       -1              0
# ...              ...           ...            ...      ...            ...
# 8921810 -2497.763672  30773.214844       0.942857       -1              0
# 8921811          NaN           NaN            NaN       -1              0
# 8921812  -936.144836  10031.811523       0.975000       -1              0
# 8921813  -101.526367   5160.858398       0.972973       -1              0
# 8921814   253.181046   9544.774414       0.972222       -1              0
#
#          TrackType
# MC_key
# 0                T
# 1               NA
# 2               NA
# 3               NA
# 4               NA
# ...            ...
# 8921810         NA
# 8921811         NA
# 8921812         NA
# 8921813         NA
# 8921814         NA
#
# [8921815 rows x 65 columns]

# %%
df_mc = pd.merge(df_truth.loc[df_truth['Rec_key'] >= 0], df_reco, left_index=True, right_on='MC_key')
df_mc = df_mc.loc[(df_mc['MC_key'] >= 0) & (df_mc['Rec_key'] >= 0)]
df_mc
# Out:
#          MCTRUTH_Lb_ENDVERTEX_X  MCTRUTH_Lb_ENDVERTEX_Y  \
# Rec_key
# 0                        0.9512                 -0.1669
# 1                        0.8237                 -0.2123
# 2                       -0.4798                 -0.7758
# 3                        1.6829                 -2.2522
# 5                        2.2347                 -3.0136
# ...                         ...                     ...
# 366391                   0.9741                  0.2091
# 366392                  -0.5103                  1.2180
# 366393                   0.1275                 -0.0589
# 366394                   1.0493                 -0.0526
# 366395                   1.3503                  0.1386
#
#          MCTRUTH_Lb_ENDVERTEX_Z  MCTRUTH_L_ENDVERTEX_X  MCTRUTH_L_ENDVERTEX_Y  \
# Rec_key
# 0                     26.401600             343.742889            -192.429398
# 1                      3.514200             140.238602             325.837311
# 2                     18.706800            -785.810974            -591.072998
# 3                    -36.520901              94.709503            -270.525391
# 5                     -3.515400             -41.785000            -495.398499
# ...                         ...                    ...                    ...
# 366391               -11.659000             294.090698              39.875000
# 366392                21.928400            -148.940399             123.715599
# 366393                25.113001            -123.851601             -28.034100
# 366394               -14.365200              24.636101            -103.056702
# 366395                79.210602             466.216705            -259.777405
#
#          MCTRUTH_L_ENDVERTEX_Z  MCTRUTH_p_PX  MCTRUTH_p_PY   MCTRUTH_p_PZ  \
# Rec_key
# 0                  4751.548828   2031.640015  -1218.119995   29336.890625
# 1                  7463.102539    367.250000   1035.959961   24602.169922
# 2                  5157.507812  -5172.310059  -3904.530029   34147.730469
# 3                  3823.881348   5635.350098 -15984.469727  230495.453125
# 5                  2890.112793   -144.789993  -1430.229980    8650.469727
# ...                        ...           ...           ...            ...
# 366391             7125.287109   2412.750000    405.109985   60216.011719
# 366392             7319.557129  -1238.500000    978.909973   57653.351562
# 366393             2985.664307  -6471.830078  -1487.530029  153226.906250
# 366394             3838.916504    267.079987  -1383.319946   50956.210938
# 366395             6610.807129   2698.139893  -1513.589966   37878.039062
#
#          MCTRUTH_pim_PX  ...  DTF_FixJPsiLambda_PIDSubs_p_PY  \
# Rec_key                  ...
# 0            445.510010  ...                     -186.566345
# 1            174.279999  ...                      222.666214
# 2           -470.119995  ...                     -323.442810
# 3            604.909973  ...                    -1702.511353
# 5            -27.309999  ...                     -514.345398
# ...                 ...  ...                             ...
# 366391       395.200012  ...                      -18.306223
# 366392       -45.599998  ...                      -50.586430
# 366393      -561.440002  ...                     -133.646973
# 366394        70.400002  ...                      -92.683861
# 366395       182.729996  ...                      -79.852051
#
#          DTF_FixJPsiLambda_PIDSubs_p_PZ  DTF_FixJPsiLambda_PIDSubs_mum_PX  \
# Rec_key
# 0                           5411.963379                       -804.469727
# 1                           4137.976074                       -605.608093
# 2                           2628.927246                          4.108163
# 3                          24506.517578                       8712.822266
# 5                           2560.247559                       2766.051025
# ...                                 ...                               ...
# 366391                      7767.518555                       1504.345581
# 366392                     -2812.631592                      -3547.666504
# 366393                     15975.192383                      -3526.683594
# 366394                      3969.945801                       1982.495117
# 366395                      1969.780762                       2975.557617
#
#          DTF_FixJPsiLambda_PIDSubs_mum_PY  DTF_FixJPsiLambda_PIDSubs_mum_PZ  \
# Rec_key
# 0                             -535.944397                      22858.960938
# 1                              594.454895                      11170.495117
# 2                             -790.314697                       5651.807129
# 3                           -18033.572266                     231397.500000
# 5                            -6544.098633                      37503.421875
# ...                                   ...                               ...
# 366391                         715.472656                      49351.718750
# 366392                        1885.741577                      33505.289062
# 366393                        -343.335175                      44636.988281
# 366394                       -2486.259033                      26074.431641
# 366395                       -1001.848267                      23227.001953
#
#          DTF_FixJPsiLambda_PIDSubs_mup_PX  DTF_FixJPsiLambda_PIDSubs_mup_PY  \
# Rec_key
# 0                             1438.071777                       1619.347290
# 1                               71.893692                      -2873.631348
# 2                            -5579.078613                       -431.151581
# 3                              336.531647                      -3496.248779
# 5                             4405.509766                      -5917.182129
# ...                                   ...                               ...
# 366391                        -112.221489                       2933.706299
# 366392                       -1337.816284                       1466.083374
# 366393                       -3534.635254                      -3121.734619
# 366394                        2165.314453                        -46.072693
# 366395                        6022.983887                       2011.241821
#
#          DTF_FixJPsiLambda_PIDSubs_mup_PZ  TrackType_y   MC_key
# Rec_key
# 0                            23634.302734            T        0
# 1                            73489.484375            T       29
# 2                            23151.667969            T       69
# 3                            45100.238281            T      119
# 5                            27155.025391            T      202
# ...                                   ...          ...      ...
# 366391                       37641.914062            T  8921673
# 366392                       45027.328125            T  8921702
# 366393                       91762.195312            T  8921772
# 366394                       39433.843750            T  8921784
# 366395                       61724.515625            T  8921805
#
# [307460 rows x 219 columns]

# %%
try:
    del(df_truth)
except NameError:
    pass

try:
    del(df_reco)
except NameError:
    pass

# %% [markdown]
# ## Prefilter

# %%
jpsi_pdg_mass = 3096.900

# %%
def p_modulus(px, py, pz):
    return np.sqrt(px**2 + py**2 + pz**2)

def transverse_p_modulus(px, py):
    return np.sqrt(px**2 + py**2)

# %%
## Missing "combined" invariant masses (for Lambda->p pim and Lambdab->JPsi Lambda)
## These are the AM in the DaVinci config file. Did Salvatore implement them somewhere?

pion_p_cuts = (
    (p_modulus(df_mc['pim_PX'], df_mc['pim_PY'], df_mc['pim_PZ']) > 2000)
    & (p_modulus(df_mc['pim_PX'], df_mc['pim_PY'], df_mc['pim_PZ']) < 5e5)
)

proton_p_cuts = (
    (p_modulus(df_mc['p_PX'], df_mc['p_PY'], df_mc['p_PZ']) > 10000)
    & (p_modulus(df_mc['p_PX'], df_mc['p_PY'], df_mc['p_PZ']) < 5e5)
)

proton_pt_cuts = transverse_p_modulus(df_mc['p_PX'], df_mc['p_PY']) > 400

lambda_m_cuts = (df_mc['L_M'] > 600) & (df_mc['L_M'] < 1500)
lambda_mm_cuts = df_mc['L_MM'] < 1500
lambda_z_cuts = (df_mc['L_ENDVERTEX_Z'] > 5500) & (df_mc['L_ENDVERTEX_Z'] < 8500)
lambda_dira_cuts = df_mc['L_BPVDIRA'] > 0.9999
lambda_ipchi2_cuts = df_mc['L_BPVIPCHI2'] < 200
lambda_vdchi2_cuts = df_mc['L_BPVVDCHI2'] < 2e7
lambda_chi2_cuts = df_mc['L_VFASPF_CHI2_VDOF'] < 750
lambda_pt_cuts = transverse_p_modulus(df_mc['L_PX'], df_mc['L_PY']) > 450

jpsi_m_cuts = abs(df_mc['Jpsi_M'] - jpsi_pdg_mass) < 90

lambdab_m_cuts = df_mc['Lb_M'] < 8500
lambdab_dira_cuts = abs(df_mc['Lb_BPVDIRA']) > 0.99
lambdab_ipchi2_cuts = df_mc['Lb_BPVIPCHI2'] < 1750
lambdab_chi2_cuts = df_mc['Lb_VFASPF_CHI2_VDOF'] < 150

dtf_success_cuts = df_mc['DTF_FixJPsiLambda_status'] == 'Success'

# %%
pre_selection_cuts = (
    pion_p_cuts &
    proton_p_cuts &
    proton_pt_cuts &
    lambda_m_cuts &
    lambda_mm_cuts &
    lambda_z_cuts &
    lambda_dira_cuts &
    lambda_ipchi2_cuts &
    lambda_vdchi2_cuts &
    lambda_chi2_cuts &
    lambda_pt_cuts &
    jpsi_m_cuts &
    lambdab_m_cuts &
    lambdab_dira_cuts &
    lambdab_ipchi2_cuts &
    lambdab_chi2_cuts
)

if dtf_success:
    pre_selection_cuts = pre_selection_cuts & dtf_success_cuts

df_mc[pre_selection_cuts]
# Out:
#          MCTRUTH_Lb_ENDVERTEX_X  MCTRUTH_Lb_ENDVERTEX_Y  \
# Rec_key
# 1                        0.8237                 -0.2123
# 14                       0.9904                 -0.2075
# 17                       0.8236                 -0.2738
# 22                       0.7534                 -0.2931
# 23                       0.6816                 -0.1256
# ...                         ...                     ...
# 366327                   0.1985                 -0.1576
# 366331                   0.8633                  0.1466
# 366333                   1.1884                 -0.0951
# 366382                   1.1575                 -0.3940
# 366391                   0.9741                  0.2091
#
#          MCTRUTH_Lb_ENDVERTEX_Z  MCTRUTH_L_ENDVERTEX_X  MCTRUTH_L_ENDVERTEX_Y  \
# Rec_key
# 1                      3.514200             140.238602             325.837311
# 14                    -9.769600             224.561996              56.081600
# 17                    28.986401            -296.374695            -100.123802
# 22                    -1.211400             -38.645302            -105.471802
# 23                   -69.357803            -842.685730             554.711914
# ...                         ...                    ...                    ...
# 366327               -19.471500            -207.092300             -37.506302
# 366331               -68.771400             -63.068901            -245.641098
# 366333                69.203400             111.651604              74.976997
# 366382                43.910599               4.075100            -146.877396
# 366391               -11.659000             294.090698              39.875000
#
#          MCTRUTH_L_ENDVERTEX_Z  MCTRUTH_p_PX  MCTRUTH_p_PY   MCTRUTH_p_PZ  \
# Rec_key
# 1                  7463.102539    367.250000   1035.959961   24602.169922
# 14                 5921.048828   2894.560059    699.140015   74302.851562
# 17                 5963.561523  -1268.760010   -522.340027   25478.310547
# 22                 7776.826172   -649.429993  -1605.150024  113660.250000
# 23                 4903.516602  -4999.830078   3343.699951   29197.720703
# ...                        ...           ...           ...            ...
# 366327             6777.450195  -2266.669922   -458.640015   76301.921875
# 366331             6745.173828   -477.579987  -2102.550049   59762.968750
# 366333             6779.822754   1028.930054    635.940002   62082.968750
# 366382             7409.937500    133.949997  -2934.969971  147684.812500
# 366391             7125.287109   2412.750000    405.109985   60216.011719
#
#          MCTRUTH_pim_PX  ...  DTF_FixJPsiLambda_PIDSubs_p_PY  \
# Rec_key                  ...
# 1            174.279999  ...                      222.666214
# 14           293.929993  ...                      104.645416
# 17          -184.460007  ...                       20.153040
# 22           -26.830000  ...                     -212.451355
# 23         -1027.900024  ...                      608.672302
# ...                 ...  ...                             ...
# 366327      -294.079987  ...                       11.039152
# 366331      -199.369995  ...                     -527.474792
# 366333       293.480011  ...                      359.789764
# 366382       -69.339996  ...                     -295.752747
# 366391       395.200012  ...                      -18.306223
#
#          DTF_FixJPsiLambda_PIDSubs_p_PZ  DTF_FixJPsiLambda_PIDSubs_mum_PX  \
# Rec_key
# 1                           4137.976074                       -605.608093
# 14                         10220.954102                       -884.967468
# 17                          3543.737305                       -829.315674
# 22                         21583.396484                      -1120.001343
# 23                          6324.328125                      -4228.179688
# ...                                 ...                               ...
# 366327                      7001.399414                        -21.106155
# 366331                     12987.607422                      -1450.088257
# 366333                     23482.865234                        860.183899
# 366382                     15403.834961                        196.509079
# 366391                      7767.518555                       1504.345581
#
#          DTF_FixJPsiLambda_PIDSubs_mum_PY  DTF_FixJPsiLambda_PIDSubs_mum_PZ  \
# Rec_key
# 1                              594.454895                      11170.495117
# 14                             195.843964                      34903.839844
# 17                            -926.117676                      37815.328125
# 22                             617.919861                      42654.800781
# 23                            1785.341675                      18403.882812
# ...                                   ...                               ...
# 366327                         590.822510                       6469.677734
# 366331                       -2851.202637                      36621.058594
# 366333                        -878.939331                      13367.183594
# 366382                        -679.625732                       6668.261719
# 366391                         715.472656                      49351.718750
#
#          DTF_FixJPsiLambda_PIDSubs_mup_PX  DTF_FixJPsiLambda_PIDSubs_mup_PY  \
# Rec_key
# 1                               71.893692                      -2873.631348
# 14                            1645.699585                      -1113.117432
# 17                            2614.833252                      -1553.520630
# 22                           -1715.901855                      -2823.659180
# 23                            -106.489746                       -762.340759
# ...                                   ...                               ...
# 366327                       -4038.527100                      -3013.788818
# 366331                        -248.967667                        760.289551
# 366333                         371.847900                      -2149.595215
# 366382                        3547.472900                      -3286.872803
# 366391                        -112.221489                       2933.706299
#
#          DTF_FixJPsiLambda_PIDSubs_mup_PZ  TrackType_y   MC_key
# Rec_key
# 1                            73489.484375            T       29
# 14                           24484.212891            T      367
# 17                           63936.839844            T      493
# 22                           61855.921875            T      557
# 23                            4744.328613            T      572
# ...                                   ...          ...      ...
# 366327                       66493.257812            T  8920122
# 366331                        5327.538574            T  8920230
# 366333                      118211.546875            T  8920398
# 366382                      190998.375000            T  8921603
# 366391                       37641.914062            T  8921673
#
# [52686 rows x 219 columns]

# %% [markdown]
# # Overall bias

# %%
def plot_series_histogram(
    series: pd.Series,
    binning: int,
    x_range: Tuple[float],
    title: str,
    x_label: str,
    file_name: str,
    zero_vline: bool = False,
    log_scale: bool = False,
    show_title: bool = True,
    show_grid: bool = True,
    black_and_white: bool = False,
    scientific_notation: bool = False,
    selection: pd.Series = None
) -> None:
    
    if selection is None:
        selection = pre_selection_cuts
    
    ## Common plot parameters
    common_plot_params = {
        'range': x_range,
        'bins': binning,
    }
    
    ## With color or b&w?
    if black_and_white:
        common_plot_params['histtype'] = 'stepfilled'
        common_plot_params['edgecolor'] = 'black'
        common_plot_params['color'] = 'gainsboro' 
        common_plot_params['hatch'] = '//' 
    else:
        common_plot_params['color'] = 'goldenrod'
        
    ## With pre-selection cuts
    plt.hist(series.loc[selection], **common_plot_params)
    
    if zero_vline:
        plt.axvline(0, 0, 100, color='black', linestyle='--')
    
    if log_scale:
        plt.yscale('log')
    
    if show_grid:
        plt.grid()
        
    if scientific_notation:
        plt.ticklabel_format(axis="x", style="sci", scilimits=(0,0))
    
    plt.xlabel(x_label)
    plt.ylabel("Events")
        
    if show_title:
        plt.title(title + '\n(MC simulation)')
    
    if save_plots:
        plt.savefig(plot_directory + file_name + '.pdf', bbox_inches = 'tight')

    plt.show()

# %%
def plot_series_hist2d(
    series_x: pd.Series,
    series_y: pd.Series,
    label_x: str,
    label_y: str,
    range_x: List[float],
    range_y: List[float],
    title: str,
    binning: int,
    file_name: str,
    show_title: bool = True,
    black_and_white: bool = False,
    selection: pd.Series = None
) -> None:
    
    plot_params = {
        'range': [range_x, range_y],
        'bins': binning
    }
    
    if black_and_white:
        plot_params['cmap'] = 'gray'
    else:
        plot_params['cmap'] = 'turbo'
        
    if selection is None:
        selection = pre_selection_cuts
    
    plt.hist2d(series_x.loc[selection], series_y.loc[selection], **plot_params)
    
    if show_title:
        plt.title(title + '\n(MC simulation)')
    
    plt.xlabel(label_x)
    plt.ylabel(label_y)
    plt.colorbar(label='Events')
    
    if save_plots:
        plt.savefig(plot_directory + file_name + '.pdf', bbox_inches = 'tight')
    
    plt.show()

# %%
def plot_series_scatter(
    series_x: pd.Series,
    series_y: pd.Series,
    range_x: List[float],
    range_y: List[float],
    label_x: str,
    label_y: str,
    title: str,
    file_name: str,
    show_title: bool = True,
    black_and_white: bool = False,
    selection: pd.Series = None
) -> None:
    
    plot_params = {
        'marker': 'o',
        's': 10
    }
    
    if black_and_white:
        plot_params['facecolors'] = 'none'
        plot_params['edgecolors'] = 'black'
    else:
        plot_params['color'] = 'goldenrod'
        
    if selection is None:
        selection = pre_selection_cuts
    
    plt.scatter(series_x.loc[selection], series_y.loc[selection], **plot_params)
    
    if show_title:
        plt.title(title + '\n(MC simulation)')
        
    plt.xlim(range_x)
    plt.ylim(range_y)
    
    plt.xlabel(label_x)
    plt.ylabel(label_y)
    
    if save_plots:
        plt.savefig(plot_directory + file_name + '.pdf', bbox_inches = 'tight')
    
    plt.show()

# %%
plot_parameters = {
    'binning': 100,
    'x_range': (-1000, 2000),
    'title': '$\Lambda^0$ decay vertex: $z$ bias',
    'x_label': '$z_\Lambda^{VF} - z_\Lambda^{true}$ [mm]',
    'file_name': 'Lambda_endvertex_bias_z',
    'zero_vline': False,
    'log_scale': False,
    'show_title': show_titles,
    'black_and_white': bw,
    'show_grid': show_grid,
}

plot_series_histogram(
    df_mc['L_ENDVERTEX_Z'] - df_mc['MCTRUTH_L_ENDVERTEX_Z'],
    **plot_parameters)

# %% [markdown]
# # Explore "the bump"

# %%
plot_parameters = {
    'binning': 100,
    'x_range': (-1000, 8500),
    'title': '$\Lambda^0$ decay vertex: $z$ bias',
    'x_label': '$z_\Lambda^{VF} - z_\Lambda^{true}$ [mm]',
    'file_name': 'Lambda_endvertex_bias_z_log',
    'zero_vline': True,
    'log_scale': True,
    'show_title': show_titles,
    'black_and_white': bw,
    'show_grid': show_grid,
}

plot_series_histogram(
    df_mc['L_ENDVERTEX_Z'] - df_mc['MCTRUTH_L_ENDVERTEX_Z'],
    **plot_parameters)

# %%
bump_min = 2000
bump_max = max(df_mc['L_ENDVERTEX_Z'] - df_mc['MCTRUTH_L_ENDVERTEX_Z'])

bump_cuts = (
    (df_mc['L_ENDVERTEX_Z'] - df_mc['MCTRUTH_L_ENDVERTEX_Z'] >= bump_min)
    & (df_mc['L_ENDVERTEX_Z'] - df_mc['MCTRUTH_L_ENDVERTEX_Z'] <= bump_max)
    & pre_selection_cuts
)

# %%
print("Total number of bump events:\t\t", sum(bump_cuts))
print("Fraction of bump events over total:\t", sum(bump_cuts)/sum(pre_selection_cuts))
# Out:
# Total number of bump events:		 885
# Fraction of bump events over total:	 0.016797631249288236

# %%
plot_parameters = {
    'binning': 100,
    'x_range': (0, 8500),
    'title': '$\Lambda^0$ decay vertex: $z$ bias',
    'x_label': '$z_\Lambda^{VF} - z_\Lambda^{true}$ [mm]',
    'file_name': 'bump_Lambda_endvertex_bias_z_log',
    'zero_vline': False,
    'log_scale': False,
    'show_title': show_titles,
    'black_and_white': bw,
    'show_grid': show_grid,
    'selection': bump_cuts
}

plot_series_histogram(
    df_mc['L_ENDVERTEX_Z'] - df_mc['MCTRUTH_L_ENDVERTEX_Z'],
    **plot_parameters)

# %%
component_to_x_range = {
    'x': [-750, 750],
    'y': [-750, 750],
    'z': [5500,8500]
}

for comp_x, comp_y in [('x', 'y'), ('z', 'x'), ('z', 'y')]:
    plot_parameters = {
        'binning': 30,
        'range_x': component_to_x_range[comp_x],
        'range_y': component_to_x_range[comp_y],
        'title': '$\Lambda^0$ decay vertex: reconstructed $' + comp_x + '$ vs. $' + comp_y + '$',
        'label_x': '$' +  comp_x + '_\Lambda^{VF}$ [mm]',
        'label_y': '$' +  comp_y + '_\Lambda^{VF}$ [mm]',
        'file_name': 'bump_hist2d_Lambda_endvertex_' + comp_x + '_vs_' + comp_y,
        'show_title': show_titles,
        'black_and_white': bw,
        'selection': bump_cuts
    }
    
    plot_series_hist2d(
        df_mc['L_ENDVERTEX_' + comp_x.upper()],
        df_mc['L_ENDVERTEX_' + comp_y.upper()],
        **plot_parameters
    )

# %%
component_to_x_range = {
    'x': [-750, 750],
    'y': [-750, 750],
    'z': [5500,8500]
}

for comp_x, comp_y in [('x', 'y'), ('z', 'x'), ('z', 'y')]:
    plot_parameters = {
        'range_x': component_to_x_range[comp_x],
        'range_y': component_to_x_range[comp_y],
        'title': '$\Lambda^0$ decay vertex: reconstructed $' + comp_x + '$ vs. $' + comp_y + '$',
        'label_x': '$' +  comp_x + '_\Lambda^{VF}$ [mm]',
        'label_y': '$' +  comp_y + '_\Lambda^{VF}$ [mm]',
        'file_name': 'bump_scatter_Lambda_endvertex_' + comp_x + '_vs_' + comp_y,
        'show_title': show_titles,
        'black_and_white': bw,
        'selection': bump_cuts,
    }
    
    plot_series_scatter(
        df_mc['L_ENDVERTEX_' + comp_x.upper()],
        df_mc['L_ENDVERTEX_' + comp_y.upper()],
        **plot_parameters
    )

# %%
component_to_x_range = {
    'x': [-199, 199],
    'y': [-199, 199],
    'z': [0,4500]
}

for comp_x, comp_y in [('x', 'y'), ('z', 'x'), ('z', 'y')]:
    plot_parameters = {
        'range_x': component_to_x_range[comp_x],
        'range_y': component_to_x_range[comp_y],
        'title': '$\Lambda^0$ decay vertex: true $' + comp_x + '$ vs. $' + comp_y + '$',
        'label_x': '$' +  comp_x + '_\Lambda^{true}$ [mm]',
        'label_y': '$' +  comp_y + '_\Lambda^{true}$ [mm]',
        'file_name': 'bump_Lambda_true_endvertex_' + comp_x + '_vs_' + comp_y,
        'show_title': show_titles,
        'black_and_white': bw,
        'selection': bump_cuts,
    }
    
    plot_series_scatter(
        df_mc['MCTRUTH_L_ENDVERTEX_' + comp_x.upper()],
        df_mc['MCTRUTH_L_ENDVERTEX_' + comp_y.upper()],
        **plot_parameters
    )

# %% [markdown]
# How many events are we talking about, dawg?

# %%
sum(bump_cuts) / sum(pre_selection_cuts)
# Out:
# 0.016797631249288236

# %% [markdown]
# # Link between horizontality and bias

# %% [markdown]
# Okay, I'll be honest: apparently I created a HDF5 file including the magnet polarity (or, at least, separating MagUp and MagDown), probably hijacking Salvatore's notebook. I have no idea when. I have no idea how similar it is to the `df_mc` I've used so far.
#
# Good for me anyway, I needed it for this study :^)

# %% [markdown]
# ## Import data with magnet polarity information

# %%
input_mc_magupdown = str(pathlib.Path.home()) + '/data/MAGUPDOWN_LHCbMC_Lb2JPsiL_ALL.h5'

# %%
df_magup = pd.read_hdf(input_mc_magupdown, key='LHCbMC_MagUp')
df_magdown = pd.read_hdf(input_mc_magupdown, key='LHCbMC_MagDown')

# %%
df_magup['Polarity'] = +1
df_magdown['Polarity'] = -1

# %%
df_mc_magupdown = pd.concat([df_magup, df_magdown], ignore_index=True)
df_mc_magupdown
# Out:
#         Lb_ENDVERTEX_X  Lb_ENDVERTEX_Y  Lb_ENDVERTEX_Z  L_ENDVERTEX_X  \
# 0             0.531989        0.156184      -11.605191    -990.557041
# 1             0.528757       -0.070308       -0.085964    -180.519168
# 2             0.859428       -0.376049       29.521646     -82.626349
# 3             0.933587       -0.165953      -28.980723     113.230367
# 4             0.836371       -0.127803      -36.125244     128.102391
# ...                ...             ...             ...            ...
# 366391        1.280367       -0.186221      -31.547196     894.704440
# 366392        1.271159       -0.350343        6.626092     336.167222
# 366393        0.949503        0.372691       38.086360     158.187917
# 366394        0.667880       -0.200282       31.615003    -149.923019
# 366395        1.291937       -0.023600       24.670748      14.643183
#
#         L_ENDVERTEX_Y  L_ENDVERTEX_Z  Jpsi_ENDVERTEX_X  Jpsi_ENDVERTEX_Y  \
# 0         -155.257567    7681.106228            0.5413            0.1391
# 1         -133.057595    7569.258412            0.5293           -0.0706
# 2         -331.621786    4814.597517            0.8603           -0.3764
# 3          -74.224539    4443.563975            0.9336           -0.1660
# 4         -220.857899    4732.615341            0.8364           -0.1278
# ...               ...            ...               ...               ...
# 366391    -344.928098    7130.349351            1.2804           -0.1862
# 366392     -21.463709    5906.546731            1.2705           -0.3499
# 366393     386.794126    3645.829919            0.9495            0.3727
# 366394      18.522700    7679.417786            0.6673           -0.2004
# 366395       3.959373     600.439386            1.2919           -0.0235
#
#         Jpsi_ENDVERTEX_Z         L_PX  ...  MCTRUTH_mup_Reconstructible  \
# 0               -11.7045 -2907.631194  ...                            2
# 1                -0.0969 -1120.822842  ...                            2
# 2                29.5380   575.017171  ...                            2
# 3               -28.9808  3718.929704  ...                            2
# 4               -36.1245  4125.442640  ...                            2
# ...                  ...          ...  ...                          ...
# 366391          -31.5470  7387.348571  ...                            2
# 366392            6.6130  4606.784224  ...                            2
# 366393           38.0864  2568.751484  ...                            2
# 366394           31.6097 -2221.075252  ...                            2
# 366395           24.6705   592.246081  ...                            2
#
#         MCTRUTH_mum_Reconstructible  MCTRUTH_Lb_Reconstructed  \
# 0                                 2                         0
# 1                                 2                         0
# 2                                 2                         0
# 3                                 2                         0
# 4                                 2                         0
# ...                             ...                       ...
# 366391                            2                         0
# 366392                            2                         0
# 366393                            2                         0
# 366394                            2                         0
# 366395                            2                         0
#
#         MCTRUTH_L_Reconstructed  MCTRUTH_p_Reconstructed  \
# 0                             0                        4
# 1                             0                        4
# 2                             0                        4
# 3                             0                        4
# 4                             0                        4
# ...                         ...                      ...
# 366391                        0                        4
# 366392                        0                        4
# 366393                        0                        4
# 366394                        0                        4
# 366395                        0                        4
#
#         MCTRUTH_pim_Reconstructed  MCTRUTH_Jpsi_Reconstructed  \
# 0                               4                           0
# 1                               4                           0
# 2                               4                           0
# 3                               4                           0
# 4                               4                           0
# ...                           ...                         ...
# 366391                          4                           0
# 366392                          4                           0
# 366393                          4                           0
# 366394                          4                           0
# 366395                          4                           0
#
#         MCTRUTH_mup_Reconstructed  MCTRUTH_mum_Reconstructed  Polarity
# 0                               1                          1         1
# 1                               1                          1         1
# 2                               1                          1         1
# 3                               1                          1         1
# 4                               1                          1         1
# ...                           ...                        ...       ...
# 366391                          1                          1        -1
# 366392                          1                          1        -1
# 366393                          1                          1        -1
# 366394                          1                          1        -1
# 366395                          1                          1        -1
#
# [366396 rows x 139 columns]

# %%
try:
    del(df_magup)
except NameError:
    pass

try:
    del(df_magdown)
except NameError:
    pass

# %% [markdown]
# ### Prefilter

# %%
## Missing "combined" invariant masses (for Lambda->p pim and Lambdab->JPsi Lambda)
## These are the AM in the DaVinci config file. Did Salvatore implement them somewhere?

pion_p_cuts_magupdown = (
    (p_modulus(df_mc_magupdown['pim_PX'], df_mc_magupdown['pim_PY'], df_mc_magupdown['pim_PZ']) > 2000)
    & (p_modulus(df_mc_magupdown['pim_PX'], df_mc_magupdown['pim_PY'], df_mc_magupdown['pim_PZ']) < 5e5)
)

proton_p_cuts_magupdown = (
    (p_modulus(df_mc_magupdown['p_PX'], df_mc_magupdown['p_PY'], df_mc_magupdown['p_PZ']) > 10000)
    & (p_modulus(df_mc_magupdown['p_PX'], df_mc_magupdown['p_PY'], df_mc_magupdown['p_PZ']) < 5e5)
)

proton_pt_cuts_magupdown = transverse_p_modulus(df_mc_magupdown['p_PX'], df_mc_magupdown['p_PY']) > 400

lambda_m_cuts_magupdown = (df_mc_magupdown['L_M'] > 600) & (df_mc_magupdown['L_M'] < 1500)
lambda_mm_cuts_magupdown = df_mc_magupdown['L_MM'] < 1500
lambda_z_cuts_magupdown = (df_mc_magupdown['L_ENDVERTEX_Z'] > 5500) & (df_mc_magupdown['L_ENDVERTEX_Z'] < 8500)
lambda_dira_cuts_magupdown = df_mc_magupdown['L_BPVDIRA'] > 0.9999
lambda_ipchi2_cuts_magupdown = df_mc_magupdown['L_BPVIPCHI2'] < 200
lambda_vdchi2_cuts_magupdown = df_mc_magupdown['L_BPVVDCHI2'] < 2e7
lambda_chi2_cuts_magupdown = df_mc_magupdown['L_VFASPF_CHI2_VDOF'] < 750
lambda_pt_cuts_magupdown = transverse_p_modulus(df_mc_magupdown['L_PX'], df_mc_magupdown['L_PY']) > 450

jpsi_m_cuts_magupdown = abs(df_mc_magupdown['Jpsi_M'] - jpsi_pdg_mass) < 90

lambdab_m_cuts_magupdown = df_mc_magupdown['Lb_M'] < 8500
lambdab_dira_cuts_magupdown = abs(df_mc_magupdown['Lb_BPVDIRA']) > 0.99
lambdab_ipchi2_cuts_magupdown = df_mc_magupdown['Lb_BPVIPCHI2'] < 1750
lambdab_chi2_cuts_magupdown = df_mc_magupdown['Lb_VFASPF_CHI2_VDOF'] < 150

dtf_success_cuts_magupdown = df_mc_magupdown['DTF_FixJPsiLambda_status'] == 0

# %%
pre_selection_cuts_magupdown = (
    pion_p_cuts_magupdown &
    proton_p_cuts_magupdown &
    proton_pt_cuts_magupdown &
    lambda_m_cuts_magupdown &
    lambda_mm_cuts_magupdown &
    lambda_z_cuts_magupdown &
    lambda_dira_cuts_magupdown &
    lambda_ipchi2_cuts_magupdown &
    lambda_vdchi2_cuts_magupdown &
    lambda_chi2_cuts_magupdown &
    lambda_pt_cuts_magupdown &
    jpsi_m_cuts_magupdown &
    lambdab_m_cuts_magupdown &
    lambdab_dira_cuts_magupdown &
    lambdab_ipchi2_cuts_magupdown &
    lambdab_chi2_cuts_magupdown
)

if dtf_success:
    pre_selection_cuts_magupdown = pre_selection_cuts_magupdown & dtf_success_cuts_magupdown

df_mc_magupdown[pre_selection_cuts_magupdown]
# Out:
#         Lb_ENDVERTEX_X  Lb_ENDVERTEX_Y  Lb_ENDVERTEX_Z  L_ENDVERTEX_X  \
# 0             0.531989        0.156184      -11.605191    -990.557041
# 1             0.528757       -0.070308       -0.085964    -180.519168
# 29           -0.132784        0.046679       55.325027     -99.791062
# 57            0.825889        0.119822       54.432073     122.668574
# 62            0.901012       -0.089617      -16.149775     170.681782
# ...                ...             ...             ...            ...
# 366385        1.054147       -0.204398      -13.725072     258.815804
# 366386        0.682150        1.136524      -30.912636    -154.194616
# 366390        0.862683       -0.108322        7.186957     182.952143
# 366391        1.280367       -0.186221      -31.547196     894.704440
# 366394        0.667880       -0.200282       31.615003    -149.923019
#
#         L_ENDVERTEX_Y  L_ENDVERTEX_Z  Jpsi_ENDVERTEX_X  Jpsi_ENDVERTEX_Y  \
# 0         -155.257567    7681.106228            0.5413            0.1391
# 1         -133.057595    7569.258412            0.5293           -0.0706
# 29         385.890429    8044.929898           -0.1319            0.0467
# 57         313.027531    7243.676180            0.8259            0.1198
# 62         -28.298653    5887.891854            0.9010           -0.0895
# ...               ...            ...               ...               ...
# 366385    -322.750637    5558.222533            1.0541           -0.2044
# 366386     350.182359    7092.914947            0.6822            1.1365
# 366390     -21.831407    6952.368667            0.8628           -0.1082
# 366391    -344.928098    7130.349351            1.2804           -0.1862
# 366394      18.522700    7679.417786            0.6673           -0.2004
#
#         Jpsi_ENDVERTEX_Z         L_PX  ...  MCTRUTH_mup_Reconstructible  \
# 0               -11.7045 -2907.631194  ...                            2
# 1                -0.0969 -1120.822842  ...                            2
# 29               55.3094  -330.482936  ...                            2
# 57               54.4319   823.667037  ...                            2
# 62              -16.1497  1004.109946  ...                            2
# ...                  ...          ...  ...                          ...
# 366385          -13.7267  2878.092423  ...                            2
# 366386          -30.9126  -896.444078  ...                            2
# 366390            7.1877  1921.555363  ...                            2
# 366391          -31.5470  7387.348571  ...                            2
# 366394           31.6097 -2221.075252  ...                            2
#
#         MCTRUTH_mum_Reconstructible  MCTRUTH_Lb_Reconstructed  \
# 0                                 2                         0
# 1                                 2                         0
# 29                                2                         0
# 57                                2                         0
# 62                                2                         0
# ...                             ...                       ...
# 366385                            2                         0
# 366386                            2                         0
# 366390                            2                         0
# 366391                            2                         0
# 366394                            2                         0
#
#         MCTRUTH_L_Reconstructed  MCTRUTH_p_Reconstructed  \
# 0                             0                        4
# 1                             0                        4
# 29                            0                        4
# 57                            0                        4
# 62                            0                        4
# ...                         ...                      ...
# 366385                        0                        4
# 366386                        0                        4
# 366390                        0                        4
# 366391                        0                        4
# 366394                        0                        4
#
#         MCTRUTH_pim_Reconstructed  MCTRUTH_Jpsi_Reconstructed  \
# 0                               4                           0
# 1                               4                           0
# 29                              4                           0
# 57                              4                           0
# 62                              4                           0
# ...                           ...                         ...
# 366385                          4                           0
# 366386                          4                           0
# 366390                          4                           0
# 366391                          4                           0
# 366394                          4                           0
#
#         MCTRUTH_mup_Reconstructed  MCTRUTH_mum_Reconstructed  Polarity
# 0                               1                          1         1
# 1                               1                          1         1
# 29                              1                          1         1
# 57                              1                          1         1
# 62                              1                          1         1
# ...                           ...                        ...       ...
# 366385                          1                          1        -1
# 366386                          1                          1        -1
# 366390                          1                          1        -1
# 366391                          1                          1        -1
# 366394                          1                          1        -1
#
# [43387 rows x 139 columns]

# %% [markdown]
# Yeah, less than the original dataset. As I said, I have no idea how I made this HDF5. It's good enough for this study, but it's far from weapon-grade.

# %% [markdown]
# "Horizontality" is a measure of how "horizontal" the decay plane is, i.e. its angle with the xz curving plane. Useful to check if events have been reconstructed "upside down".

# %%
def row_a_vec(row, p_pvec_column, pim_pvec_column):
    return np.cross(row[p_pvec_column], row[pim_pvec_column])

# %%
def row_a_norm(row, avec_column):
    return np.linalg.norm(row[avec_column])

# %%
def feature_component(series, component):
    return series.map(lambda x: x[component])

# %%
## This computes (once) a new column in df named 'momenta_prefix_h',
## containing the related horizontality. Returns the related column name.
def compute_horizontality(
    df: pd.DataFrame,
    momenta_prefix: str,
    p_px_column: str,
    p_py_column: str,
    p_pz_column: str,
    pim_px_column: str,
    pim_py_column: str,
    pim_pz_column :str,
):
      
    p_pvec_column = momenta_prefix + "_p_p_vec"
    pim_pvec_column = momenta_prefix + "_pim_p_vec"
    avec_column = momenta_prefix + "_a_vec"
    anorm_column = momenta_prefix + "_a_norm"
    ahat_column = momenta_prefix + "_a_hat"
    h_column = momenta_prefix + "_h"
    
    df[p_pvec_column] = list(zip(df[p_px_column], df[p_py_column], df[p_pz_column]))
    df[pim_pvec_column] = list(zip(df[pim_px_column], df[pim_py_column], df[pim_pz_column]))
    df[avec_column] = df.apply(lambda row: row_a_vec(row, p_pvec_column, pim_pvec_column), axis=1)
    df[anorm_column] = df.apply(lambda row: row_a_norm(row, avec_column), axis=1)
    df[ahat_column] = df[avec_column]/df[anorm_column]
    df[h_column] = feature_component(df[ahat_column], 1) * df['Polarity'] * np.sign(df['L_ID'])
    
    df.drop(columns=[
        p_pvec_column,
        pim_pvec_column,
        avec_column,
        anorm_column,
        ahat_column
    ], inplace=True)
    
    return h_column

# %%
h_reco_DTF = compute_horizontality(
    df=df_mc_magupdown, momenta_prefix="DTF_FixJPsiLambda",
    p_px_column='DTF_FixJPsiLambda_p_PX', p_py_column='DTF_FixJPsiLambda_p_PY', p_pz_column='DTF_FixJPsiLambda_p_PZ',
    pim_px_column='DTF_FixJPsiLambda_pim_PX', pim_py_column='DTF_FixJPsiLambda_pim_PY', pim_pz_column='DTF_FixJPsiLambda_pim_PZ'
)

# %%
h_truth = compute_horizontality(
    df=df_mc_magupdown, momenta_prefix="MCTRUTH",
    p_px_column='MCTRUTH_p_PX', p_py_column='MCTRUTH_p_PY', p_pz_column='MCTRUTH_p_PZ',
    pim_px_column='MCTRUTH_pim_PX', pim_py_column='MCTRUTH_pim_PY', pim_pz_column='MCTRUTH_pim_PZ'
)

# %%
plot_parameters = {
    'binning': 100,
    'x_range': (-2, 2),
    'title': r'$\Lambda^0 \rightarrow p\pi^-$ horizontality bias',
    'x_label': '$h_{DTF} - h_{true}$',
    'file_name': 'Lambda_horizontality_bias',
    'zero_vline': False,
    'log_scale': False,
    'show_title': show_titles,
    'black_and_white': bw,
    'show_grid': show_grid,
    'selection': pre_selection_cuts_magupdown
}

plot_series_histogram(
    df_mc_magupdown[h_reco_DTF] - df_mc_magupdown[h_truth],
    **plot_parameters)

# %% [markdown]
# Fraction of events (passing prefilters) reconstructed with $h$ bias $\geq 1$ ("upside down").

# %%
upside_down_individual_cut = df_mc_magupdown[h_reco_DTF] - df_mc_magupdown[h_truth] > 1

# %%
len(df_mc_magupdown[pre_selection_cuts_magupdown & upside_down_individual_cut]) / len(df_mc_magupdown[pre_selection_cuts_magupdown])
# Out:
# 0.25975522621983543

# %%
## Common plot parameters
common_plot_params = {
    'range': (-700,1700),
    'bins': 100,
    'histtype': 'stepfilled',
    'edgecolor': 'black',
    'facecolor': 'none',
    'density': True
}

## Individual plot parameters
right_way_up_params = {
    'hatch': '--',
    'label': '$\Delta h < 1$'
}

upside_down_params = {
    'hatch': '//',
    'label': '$\Delta h \geq 1$'
}

series = df_mc_magupdown['L_ENDVERTEX_Z'] - df_mc_magupdown['MCTRUTH_L_ENDVERTEX_Z']

## Bias < 1
plt.hist(series.loc[pre_selection_cuts_magupdown & ~upside_down_individual_cut], **common_plot_params, **right_way_up_params)

## Bias >= 1
plt.hist(series.loc[pre_selection_cuts_magupdown & upside_down_individual_cut], **common_plot_params, **upside_down_params)

if show_grid:
    plt.grid()

plt.xlabel('$z_\Lambda^{VF} - z_\Lambda^{true}$ [mm]',)
plt.ylabel("Probability density")

if show_titles:
    plt.title(r'$\Lambda^0 \rightarrow p\pi^-$: $z$ vertex bias vs. horizontality bias' + '\n(MC simulation)')

plt.legend(frameon=False)
    
if save_plots:
    plt.savefig(plot_directory + 'lambda_endvertex_z_bias_vs_horizontality_bias' + '.pdf', bbox_inches = 'tight')

plt.show()
